# %%
#scraper that addresses party change FINAL WORKING SCRAPER 2004-2009
import requests
from bs4 import BeautifulSoup
import csv
import os

# URL of the MEP directory
directory_url = "https://www.europarl.europa.eu/meps/en/directory/9"

# Directory to save the CSV file
output_directory = 

# Output CSV file path
output_file = os.path.join(output_directory, "raw_mep_data_CRE-9.csv")

print("Starting the web scraping process...")

# Make a request to the directory page
print(f"Fetching MEP directory page: {directory_url}")
response = requests.get(directory_url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find all the links to individual MEPs
print("Finding links to individual MEPs...")
mep_links = soup.find_all('a', href=True)
mep_links = [link['href'] for link in mep_links if "/meps/en/" in link['href']]

print(f"Found {len(mep_links)} MEP links.")

# Prepare the CSV file
print(f"Preparing to write data to {output_file}")
with open(output_file, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Name', 'Country', 'Party', 'Date'])

    for index, link in enumerate(mep_links):
        # If the link is already absolute, use it as is
        if link.startswith("https://"):
            mep_url = link
        else:
            # Otherwise, prepend the base URL
            mep_url = "https://www.europarl.europa.eu" + link

        print(f"Processing MEP {index + 1}/{len(mep_links)}: {mep_url}")

        try:
            mep_response = requests.get(mep_url)
            mep_response.raise_for_status()  # Raises HTTPError for bad responses
        except requests.exceptions.RequestException as e:
            print(f"Error accessing {mep_url}: {e}")
            continue

        mep_soup = BeautifulSoup(mep_response.text, 'html.parser')

        # Extract the MEP's name
        name_tag = mep_soup.find('span', class_='sln-member-name')
        name = name_tag.text.strip() if name_tag else "N/A"
        print(f"Extracted Name: {name}")

        # Extract the country
        country_tag = mep_soup.find('div', class_='erpl_title-h3 mt-1 mb-1')
        country = country_tag.text.strip() if country_tag else "N/A"
        print(f"Extracted Country: {country}")

        # Extract MEP ID and Name correctly from the original link
        mep_parts = link.split('/')
        
        # Extract MEP ID - Ensure there's a numeric part
        mep_id = None
        for part in mep_parts:
            if part.isdigit():
                mep_id = part
                break
        
        if not mep_id:
            print(f"Warning: No MEP ID found in URL {link}")
            continue  # Skip to the next MEP if no ID is found

        # Correctly format the MEP name for the fallback URL
        formatted_name = name.upper().replace(" ", "_")

        # Construct the correct URL to fetch party history
        detailed_url = f"https://www.europarl.europa.eu/meps/en/{mep_id}/{formatted_name}/history/9#detailedcardmep"
        print(f"Fetching detailed history page: {detailed_url}")

        try:
            detailed_response = requests.get(detailed_url)
            detailed_response.raise_for_status()  # Raises HTTPError for bad responses
            detailed_soup = BeautifulSoup(detailed_response.text, 'html.parser')

            # Find the div with class 'erpl_meps-status' where the political group changes are listed
            status_div = detailed_soup.find('div', class_='erpl_meps-status')
            if status_div:
                # Extract all strong tags and their associated texts within this section
                strong_tags = status_div.find_all('strong')
                for strong_tag in strong_tags:
                    date = strong_tag.text.strip()
                    party_info = strong_tag.find_next_sibling(text=True)
                    if party_info:
                        party = party_info.strip()
                        print(f"Extracted Party: {party}, Date: {date}")

                        # Write each party change as a separate row in the CSV file
                        writer.writerow([name, country, party, date])
                        print(f"Data for {name} with party {party} written to CSV.")

        except requests.exceptions.RequestException as e:
            print(f"Error accessing detailed history page {detailed_url}: {e}")

print(f"Data successfully saved to {output_file}")
# Out:
# Starting the web scraping process...
# Fetching MEP directory page: https://www.europarl.europa.eu/meps/en/directory/9
# Finding links to individual MEPs...
# Found 929 MEP links.
# Preparing to write data to C:\Users\pablo\OneDrive\Escritorio\Masters\Year_2\eu_database_project\mep_data\2019_2024_CRE9\raw\raw_mep_data_CRE-9.csv
# Processing MEP 1/929: https://www.europarl.europa.eu/meps/en/directory/9
# Extracted Name: N/A
# Extracted Country: N/A
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep
# Error accessing detailed history page https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep: 404 Client Error:  for url: https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep
# Processing MEP
# Extracted Name: N/A
# Extracted Country: N/A
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep
# Error accessing detailed history page https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep: 404 Client Error:  for url: https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep
# Processing MEP 38/929: https://www.europarl.europa.eu/meps/en/directory/9/w
# Extracted Name: N/A
# Extracted Country: N/A
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep
# Error accessing detailed history page https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep: 404 Client Error:  for url: https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep
# Processing MEP 39/929: https://www.europarl.europa.eu/meps/en/directory/9/y
# Extracted Name: N/A
# Extracted Country: N/A
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep
# Error accessing detailed history page https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep: 404 Client Error:  for url: https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep
# Processing MEP 40/929: https://www.europarl.europa.eu/meps/en/directory/9/z
# Extracted Name: N/A
# Extracted Country: N/A
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep
# Error accessing detailed history page https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep: 404 Client Error:  for url: https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep
# Processing MEP 41/929: https://www.europarl.europa.eu/meps/en/directory/9
# Extracted Name: N/A
# Extracted Country: N/A
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep
# Error accessing detailed history page https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep: 404 Client Error:  for url: https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep
# Processing MEP 42/929: https://www.europarl.europa.eu/meps/en/197490
# Extracted Name: Magdalena ADAMOWICZ
# Extracted Country: Poland
#
# 							 - Independent (Poland)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197490/MAGDALENA_ADAMOWICZ/history/9#detailedcardmep
# C:\Users\pablo\AppData\Local\Temp\ipykernel_9612\2185153911.py:98: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   party_info = strong_tag.find_next_sibling(text=True)
# Extracted Party: : Group of the European People's Party (Christian Democrats) - Member, Date: 02-07-2019 / 15-07-2024
# Data for Magdalena ADAMOWICZ with party : Group of the European People's Party (Christian Democrats) - Member written to CSV.
# Processing MEP 43/929: https://www.europarl.europa.eu/meps/en/189525
# Extracted Name: Asim ADEMOV
# Extracted Country: Bulgaria
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/189525/ASIM_ADEMOV/history/9#detailedcardmep
# Extracted Party: : Group of the European People's Party (Christian Democrats) - Member, Date: 02-07-2019 / 15-07-2024
# Data for Asim ADEMOV with party : Group of the European People's Party (Christian Democrats) - Member written to CSV.
# Processing MEP 44/929: https://www.europarl.europa.eu/meps/en/124831
# Extracted Name: Isabella ADINOLFI
# Extracted Country: Italy
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/124831/ISABELLA_ADINOLFI/history/9#detailedcardmep
# Extracted Party: : Non-attached Members, Date: 02-07-2019 / 28-04-2021
# Data for Isabella ADINOLFI with party : Non-attached Members written to CSV.
# Extracted Party: : Group of the European People's Party (Christian Democrats) - Member, Date: 29-04-2021 / 15-07-2024
# Data for Isabella ADINOLFI with party : Group of the European People's Party (Christian Democrats) - Member written to CSV.
# Processing MEP 45/929: https://www.europarl.europa.eu/meps/en/197826
# Extracted Name: Matteo ADINOLFI
# Extracted Country: Italy
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197826/MATTEO_ADINOLFI/history/9#detailedcardmep
# Extracted Party: : Identity and Democracy Group - Member, Date: 02-07-2019 / 15-07-2024
# Data for Matteo ADINOLFI with party : Identity and Democracy Group - Member written to CSV.
# Processing MEP 46/929: https://www.europarl.europa.eu/meps/en/197403
# Extracted Name: Alex AGIUS SALIBA
# Extracted Country: Malta
#
# 							 - Partit Laburista (Malta)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197403/ALEX_AGIUS_SALIBA/history/9#detailedcardmep
# Extracted Party: : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member, Date: 02-07-2019 / 15-12-2021
# Data for Alex AGIUS SALIBA with party : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member written to CSV.
# Extracted Party: : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Vice-Chair, Date: 16-12-2021 / 15-07-2024
# Data for Alex AGIUS SALIBA with party : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Vice-Chair written to CSV.
# Processing MEP 47/929: https://www.europarl.europa.eu/meps/en/198096
# Extracted Name: Mazaly AGUILAR
# Extracted Country: Spain
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/198096/MAZALY_AGUILAR/history/9#detailedcardmep
# Extracted Party: : European Conservatives and Reformists Group - Member of the Bureau, Date: 02-07-2019 / 03-03-2020
# Data for Mazaly AGUILAR with party : European Conservatives and Reformists Group - Member of the Bureau written to CSV.
# Extracted Party: : European Conservatives and Reformists Group - Member, Date: 04-03-2020 / 15-07-2024
# Data for Mazaly AGUILAR with party : European Conservatives and Reformists Group - Member written to CSV.
# Processing MEP 48/929: https://www.europarl.europa.eu/meps/en/125045
# Extracted Name: Clara AGUILERA
# Extracted Country: Spain
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/125045/CLARA_AGUILERA/history/9#detailedcardmep
# Extracted Party: : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member, Date: 02-07-2019 / 15-07-2024
# Data for Clara AGUILERA with party : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member written to CSV.
# Processing MEP 49/929: https://www.europarl.europa.eu/meps/en/197696
# Extracted Name: Scott AINSLIE
# Extracted Country: United Kingdom
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197696/SCOTT_AINSLIE/history/9#detailedcardmep
# Extracted Party: : Group of the Greens/European Free Alliance - Member, Date: 02-07-2019 / 31-01-2020
# Data for Scott AINSLIE with party : Group of the Greens/European Free Alliance - Member written to CSV.
# Processing MEP 50/929: https://www.europarl.europa.eu/meps/en/204335
# Extracted Name: Alviina ALAMETSÄ
# Extracted Country: Finland
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/204335/ALVIINA_ALAMETSÄ/history/9#detailedcardmep
# Extracted Party: : Group of the Greens/European Free Alliance - Member, Date: 01-02-2020 / 15-07-2024
# Data for Alviina ALAMETSÄ with party : Group of the Greens/European Free Alliance - Member written to CSV.
# Processing MEP 51/929: https://www.europarl.europa.eu/meps/en/237224
# Extracted Name: João ALBUQUERQUE
# Extracted Country: Portugal
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en
party : Group of the Greens/European Free Alliance - Member written to CSV.
# Processing MEP 63/929: https://www.europarl.europa.eu/meps/en/197448
# Extracted Name: Rasmus ANDRESEN
# Extracted Country: Germany
#
# 							 - Bündnis 90/Die Grünen (Germany)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197448/RASMUS_ANDRESEN/history/9#detailedcardmep
# Extracted Party: : Group of the Greens/European Free Alliance - Member, Date: 02-07-2019 / 15-07-2024
# Data for Rasmus ANDRESEN with party : Group of the Greens/European Free Alliance - Member written to CSV.
# Processing MEP 64/929: https://www.europarl.europa.eu/meps/en/204332
# Extracted Name: Barry ANDREWS
# Extracted Country: Ireland
#
# 							 - Fianna Fáil Party (Ireland)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/204332/BARRY_ANDREWS/history/9#detailedcardmep
# Extracted Party: : Renew Europe Group - Member, Date: 01-02-2020 / 15-07-2024
# Data for Barry ANDREWS with party : Renew Europe Group - Member written to CSV.
# Processing MEP 65/929: https://www.europarl.europa.eu/meps/en/113892
# Extracted Name: Eric ANDRIEU
# Extracted Country: France
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/113892/ERIC_ANDRIEU/history/9#detailedcardmep
# Extracted Party: : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - First Vice-Chair, Date: 02-07-2019 / 01-06-2023
# Data for Eric ANDRIEU with party : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - First Vice-Chair written to CSV.
# Processing MEP 66/929: https://www.europarl.europa.eu/meps/en/197691
# Extracted Name: Mathilde ANDROUËT
# Extracted Country: France
#
# 							 - Rassemblement national (France)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197691/MATHILDE_ANDROUËT/history/9#detailedcardmep
# Extracted Party: : Identity and Democracy Group - Member, Date: 02-07-2019 / 15-07-2024
# Data for Mathilde ANDROUËT with party : Identity and Democracy Group - Member written to CSV.
# Processing MEP 67/929: https://www.europarl.europa.eu/meps/en/125110
# Extracted Name: Nikos ANDROULAKIS
# Extracted Country: Greece
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/125110/NIKOS_ANDROULAKIS/history/9#detailedcardmep
# Extracted Party: : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member, Date: 02-07-2019 / 02-05-2023
# Data for Nikos ANDROULAKIS with party : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member written to CSV.
# Processing MEP 68/929: https://www.europarl.europa.eu/meps/en/202073
# Extracted Name: Marc ANGEL
# Extracted Country: Luxembourg
#
# 							 - Parti ouvrier socialiste luxembourgeois (Luxembourg)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/202073/MARC_ANGEL/history/9#detailedcardmep
# Extracted Party: : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member, Date: 10-12-2019 / 15-07-2024
# Data for Marc ANGEL with party : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member written to CSV.
# Processing MEP 69/929: https://www.europarl.europa.eu/meps/en/124973
# Extracted Name: Gerolf ANNEMANS
# Extracted Country: Belgium
#
# 							 - Vlaams Belang (Belgium)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/124973/GEROLF_ANNEMANS/history/9#detailedcardmep
# Extracted Party: : Identity and Democracy Group - Member of the Bureau, Date: 02-07-2019 / 15-07-2024
# Data for Gerolf ANNEMANS with party : Identity and Democracy Group - Member of the Bureau written to CSV.
# Processing MEP 70/929: https://www.europarl.europa.eu/meps/en/124696
# Extracted Name: Andrus ANSIP
# Extracted Country: Estonia
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/124696/ANDRUS_ANSIP/history/9#detailedcardmep
# Extracted Party: : Renew Europe Group - Member, Date: 02-07-2019 / 15-07-2024
# Data for Andrus ANSIP with party : Renew Europe Group - Member written to CSV.
# Processing MEP 71/929: https://www.europarl.europa.eu/meps/en/197587
# Extracted Name: Attila ARA-KOVÁCS
# Extracted Country: Hungary
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197587/ATTILA_ARA-KOVÁCS/history/9#detailedcardmep
# Extracted Party: : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member, Date: 02-07-2019 / 15-07-2024
# Data for Attila ARA-KOVÁCS with party : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member written to CSV.
# Processing MEP 72/929: https://www.europarl.europa.eu/meps/en/124936
# Extracted Name: Maria ARENA
# Extracted Country: Belgium
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/124936/MARIA_ARENA/history/9#detailedcardmep
# Extracted Party: : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member, Date: 02-07-2019 / 15-07-2024
# Data for Maria ARENA with party : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member written to CSV.
# Processing MEP 73/929: https://www.europarl.europa.eu/meps/en/96808
# Extracted Name: Pablo ARIAS ECHEVERRÍA
# Extracted Country: Spain
#
# 							 - Partido Popular (Spain)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/96808/PABLO_ARIAS_ECHEVERRÍA/history/9#detailedcardmep
# Extracted Party: : Group of the European People's Party (Christian Democrats) - Member, Date: 02-07-2019 / 15-07-2024
# Data for Pablo ARIAS ECHEVERRÍA with party : Group of the European People's Party (Christian Democrats) - Member written to CSV.
# Processing MEP 74/929: https://www.europarl.europa.eu/meps/en/24922
# Extracted Name: Pascal ARIMONT
# Extracted Country: Belgium
#
# 							 - Christlich Soziale Partei (Belgium)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/24922/PASCAL_ARIMONT/history/9#detailedcardmep
# Extracted Party: : Group of the European People's Party (Christian Democrats) - Member, Date: 02-07-2019 / 15-07-2024
# Data for Pascal ARIMONT with party : Group of the European People's Party (Christian Democrats) - Member written to CSV.
# Processing MEP 75/929: https://www.europarl.europa.eu/meps/en/197492
# Extracted Name: Bartosz ARŁUKOWICZ
# Extracted Country: Poland
#
# 							 - Platforma Obywatelska (Poland)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197492/BARTOSZ_ARŁUKOWICZ/history/9#detailedcardmep
# Extracted Party: : Group of the European People's Party (Christian Democrats) - Member, Date: 02-07-2019 / 18-10-2023
# Data for Bartosz ARŁUKOWICZ with party : Group of the European People's Party (Christian Democrats) - Member written to CSV.
# Processing MEP 76/929: https://www.europarl.europa.eu/meps/en/197664
# Extracted Name: Clotilde ARMAND
# Extracted Country: Romania
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197664/CLOTILDE_ARMAND/history/9#detailedcardmep
# Extracted Party: : Renew Europe Group - Member, Date: 02-07-2019 / 03-11-2020
# Data for Clotilde ARMAND with party : Renew Europe Group - Member written to CSV.
# Processing MEP 77/929: https://www.europarl.europa.eu/meps/en/197701
# Extracted Name: Konstantinos ARVANITIS
# Extracted Country: Greece
#
# 							 - Coalition of the Radical Left (Greece)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197701/KONSTANTINOS_ARVANITIS/history/9#detailedcardmep
# Extracted Party: : Group of the European United Left - Nordic Green Left - Member, Date: 02-07-2019 / 17-12-2020
# Data for Konstantinos ARVANITIS with party : Group of the European United Left - Nordic Green Left - Member written to CSV.
# Extracted Party: : The Left group in the European Parliament - GUE/NGL - Member, Date: 18-12-2020 / 15-07-2024
# Data for Konstantinos ARVANITIS with party : The Left group in the European Parliament - GUE/NGL - Member written to CSV.
# Processing MEP 78/929: https://www.europarl.europa.eu/meps/en/197695
# Extracted Name: Anna-Michelle ASIMAKOPOULOU
# Extracted Country: Greece
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197695/ANNA-MICHELLE_ASIMAKOPOULOU/history/9#detailedcardmep
# Extracted Party: : Group of the European People's Party (Christian Democrats) - Member, Date: 02-07-2019 / 15-07-2024
# Data for Anna-Michelle ASIMAKOPOULOU with party : Group of the European People's Party (Christian Democrats) - Member written to CSV.
# Processing MEP 79/929: https://www.europarl.europa.eu/meps/en/197533
# Extracted Name: Manon AUBRY
# Extracted Country: France
#
# 							 - La France Insoumise (France)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197533/MANON_AUBRY/history/9#detailedcardmep
# Extracted Party: : Group of the European United Left - Nordic Green Left - Member, Date: 02-07-2019 / 17-07-2019
# Data for Manon AUBRY with party : Group of the European United Left - Nordic Green Left - Member written to CSV.
# Extracted Party: : Group of the European United Left - Nordic Green Left - Co-Chair, Date: 18-07-2019 / 17-12-2020
# Data for Manon AUBRY with party : Group of the European United Left - Nordic Green Left - Co-Chair written to CSV.
# Extracted Party: : The Left group in the European Parliament - GUE/NGL - Co-Chair, Date: 18-12-2020 / 15-07-2024
# Data for Manon AUBRY with party : The Left group in the European Parliament - GUE/NGL - Co-Chair written to CSV.
# Processing MEP 80/929: https://www.europarl.europa.eu/meps/en/28161
# Extracted Name: Margrete AUKEN
# Extracted Country: Denmark
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/28161/MARGRETE_AUKEN/history/9#detailedcardmep
# Extracted Party: : Group of the Greens/European Free Alliance - Member, Date: 02-07-2019 / 15-07-2024
# Data for Margrete AUKEN with party : Group of the Greens/European Free Alliance - Member written to CSV.
# Processing MEP 81/929: https://www.europarl.europa.eu/meps/en/124766
# Extracted Name: Petras AUŠTREVIČIUS
# Extracted Country: Lithuania
#
# 							 - Liberalų sąjūdis (Lithuania)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/124766/PETRAS_AUŠTREVIČIUS/history/9#detailedcardmep
# Extracted Party: : Renew Europe Group - Member, Date: 02-07-2019 / 15-07-2024
# Data for Petras AUŠTREVIČIUS with party : Renew Europe Group - Member written to CSV.
# Processing MEP 82/929: https://www.europarl.europa.eu/meps/en/197651
# Extracted Name: Carmen AVRAM
# Extracted Country: Romania
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197651/CARMEN_AVRAM/history/9#detailedcardmep
# Extracted Party: : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member, Date: 02-07-2019 / 15-07-2024
# Data for Carmen AVRAM with party : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member written to CSV.
# Processing MEP 83/929: https://www.europarl.europa.eu/meps/en/197781
# Extracted Name: Malik AZMANI
# Extracted Country: Netherlands
#
# 							 - Volkspartij voor Vrijheid en Democratie (Netherlands)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197781/MALIK_AZMANI/history/9#detailedcardmep
# Extracted Party: : Renew Europe Group - First Vice-Chair, Date: 02-07-2019 / 15-07-2024
# Data for Malik AZMANI with party : Renew Europe Group - First Vice-Chair written to CSV.
# Processing MEP 84/929: https://www.europarl.europa.eu/meps/en/197789
# Extracted Name: Simona BALDASSARRE
# Extracted Country: Italy
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197789/SIMONA_BALDASSARRE/history/9#detailedcardmep
# Extracted Party: : Identity and Democracy Group - Member, Date: 02-07-2019 / 02-04-2023
# Data for Simona BALDASSARRE with party : Identity and Democracy Group - Member written to CSV.
# Processing MEP 85/929: https://www.europarl.europa.eu/meps/en/247735
# Extracted Name: Laura BALLARÍN CEREZA
# Extracted Country: Spain
#
# 							 - Partido Socialista Obrero Español (Spain)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/247735/LAURA_BALLARÍN_CEREZA/history/9#detailedcardmep
# Extracted Party: : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member, Date: 06-09-2023 / 15-07-2024
# Data for Laura BALLARÍN CEREZA with party : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member written to CSV.
# Processing MEP 86/929: https://www.europarl.europa.eu/meps/en/197495
# Extracted Name: Marek Paweł BALT
# Extracted Country: Poland
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197495/MAREK_PAWEŁ_BALT/history/9#detailedcardmep
# Extracted Party: : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member, Date: 02-07-2019 / 15-07-2024
# Data for Marek Paweł BALT with party : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member written to CSV.
# Processing MEP 87/929: https://www.europarl.europa.eu/meps/en/131580
# Extracted Name: Jordan BARDELLA
# Extracted Country: France
#
# 							 - Rassemblement national (France)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/131580/JORDAN_BARDELLA/history/9#detailedcardmep
# Extracted Party: : Identity and Democracy Group - Member, Date: 02-07-2019 / 15-07-2024
# Data for Jordan BARDELLA with party : Identity and Democracy Group - Member written to CSV.
# Processing MEP 88/929: https://www.europarl.europa.eu/meps/en/197433
# Extracted Name: Katarina BARLEY
# Extracted Country: Germany
#
# 							 - Sozialdemokratische Partei Deutschlands (Germany)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197433/KATARINA_BARLEY/history/9#detailedcardmep
# Extracted Party: : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member, Date: 02-07-2019 / 15-07-2024
# Data for Katarina BARLEY with party : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member written to CSV.
# Processing MEP 89/929: https://www.europarl.europa.eu/meps/en/197684
# Extracted Name: Pernando BARRENA ARZA
# Extracted Country: Spain
#
# 							 - EH BILDU (Spain)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197684/PERNANDO_BARRENA_ARZA/history/9#detailedcardmep
# Extracted Party: : Group of the European United Left - Nordic Green Left - Member, Date: 02-07-2019 / 17-12-2020
# Data for Pernando BARRENA ARZA with party : Group of the European United Left - Nordic Green Left - Member written to CSV.
# Extracted Party: : The Left group in the European Parliament - GUE/NGL - Member, Date: 18-12-2020 / 02-09-2022
# Data for Pernando BARRENA ARZA with party : The Left group in the European Parliament - GUE/NGL - Member written to CSV.
# Processing MEP 90/929: https://www.europarl.europa.eu/meps/en/197808
# Extracted Name: Pietro BARTOLO
# Extracted Country: Italy
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197808/PIETRO_BARTOLO/history/9#detailedcardmep
# Extracted Party: : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member, Date: 02-07-2019 / 15-07-2024
# Data for Pietro BARTOLO with party : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member written to CSV.
# Processing MEP 91/929: https://www.europarl.europa.eu/meps/en/197671
# Extracted Name: Traian BĂSESCU
# Extracted Country: Romania
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197671/TRAIAN_BĂSESCU/history/9#detailedcardmep
# Extracted Party: : Group of the European People's Party (Christian Democrats) - Member, Date: 02-07-2019 / 15-07-2024
# Data for Traian BĂSESCU with party : Group of the European People's Party (Christian Democrats) - Member written to CSV.
# Processing MEP 92/929: https://www.europarl.europa.eu/meps/en/197610
# Extracted Name: Alessandra BASSO
# Extracted Country: Italy
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197610/ALESSANDRA_BASSO/history/9#detailedcardmep
# Extracted Party: : Identity and Democracy Group - Member, Date: 02-07-2019 / 15-07-2024
# Data for Alessandra BASSO with party : Identity and Democracy Group - Member written to CSV.
# Processing MEP 93/929: https://www.europarl.europa.eu/meps/en/197779
# Extracted Name: José Ramón BAUZÁ DÍAZ
# Extracted Country: Spain
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197779/JOSÉ_RAMÓN_BAUZÁ_DÍAZ/history/9#detailedcardmep
# Extracted Party: : Renew Europe Group - Member, Date: 02-07-2019 / 15-07-2024
# Data for José Ramón BAUZÁ DÍAZ with party : Renew Europe Group - Member written to CSV.
# Processing MEP 94/929: https://www.europarl.europa.eu/meps/en/124760
# Extracted Name: Nicolas BAY
# Extracted Country: France
#
# 							 - Divers droite (France)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/124760/NICOLAS_BAY/history/9#detailedcardmep
# Extracted Party: : Identity and Democracy Group - Vice-Chair, Date: 02-07-2019 / 15-02-2022
# Data for Nicolas BAY with party : Identity and Democracy Group - Vice-Chair written to CSV.
# Extracted Party: : Non-attached Members, Date: 16-02-2022 / 06-02-2024
# Data for Nicolas BAY with party : Non-attached Members written to CSV.
# Extracted Party: : European Conservatives and Reformists Group - Member of the Bureau, Date: 07-02-2024 / 15-07-2024
# Data for Nicolas BAY with party : European Conservatives and Reformists Group - Member of the Bureau written to CSV.
# Processing MEP 95/929: https://www.europarl.europa.eu/meps/en/96955
# Extracted Name: Catherine BEARDER
# Extracted Country: United Kingdom
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/96955/CATHERINE_BEARDER/history/9#detailedcardmep
# Extracted Party: : Renew Europe Group - Member, Date: 02-07-2019 / 31-01-2020
# Data for Catherine BEARDER with party : Renew Europe Group - Member written to CSV.
# Processing MEP 96/929: https://www.europarl.europa.eu/meps/en/132191
# Extracted Name: Gunnar BECK
# Extracted Country: Germany
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/132191/GUNNAR_BECK/history/9#detailedcardmep
# Extracted Party: : Identity and Democracy Group - Member, Date: 02-07-2019 / 22-05-2024
# Data for Gunnar BECK with party : Identity and Democracy Group - Member written to CSV.
# Extracted Party: : Non-attached Members, Date: 23-05-2024 / 15-07-2024
# Data for Gunnar BECK with party : Non-attached Members written to CSV.
# Processing MEP 97/929: https://www.europarl.europa.eu/meps/en/254719
# Extracted Name: Vasco BECKER-WEINBERG
# Extracted Country: Portugal
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/254719/VASCO_BECKER-WEINBERG/history/9#detailedcardmep
# Extracted Party: : Group of the European People's Party (Christian Democrats) - Member, Date: 26-03-2024 / 15-07-2024
# Data for Vasco BECKER-WEINBERG with party : Group of the European People's Party (Christian Democrats) - Member written to CSV.
# Processing MEP 98/929: https://www.europarl.europa.eu/meps/en/197437
# Extracted Name: Nicola BEER
# Extracted Country: Germany
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197437/NICOLA_BEER/history/9#detailedcardmep
# Extracted Party: : Renew Europe Group - Member, Date: 02-07-2019 / 31-12-2023
# Data for Nicola BEER with party : Renew Europe Group - Member written to CSV.
# Processing MEP 99/929: https://www.europarl.europa.eu/meps/en/124777
# Extracted Name: Tiziana BEGHIN
# Extracted Country: Italy
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/124777/TIZIANA_BEGHIN/history/9#detailedcardmep
# Extracted Party: : Non-attached Members, Date: 02-07-2019 / 15-07-2024
# Data for Tiziana BEGHIN with party : Non-attached Members written to CSV.
# Processing MEP 100/929: https://www.europarl.europa.eu/meps/en/197680
# Extracted Name: Aurélia BEIGNEUX
# Extracted Country: France
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197680/AURÉLIA_BEIGNEUX/history/9#detailedcardmep
# Extracted Party: : Identity and Democracy Group - Member, Date: 02-07-2019 / 15-07-2024
# Data for Aurélia BEIGNEUX with party : Identity and Democracy Group - Member written to CSV.
# Processing MEP 101/929: https://www.europarl.europa.eu/meps/en/197496
# Extracted Name: Marek BELKA
# Extracted Country: Poland
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197496/MAREK_BELKA/history/9#detailedcardmep
# Extracted Party: : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member, Date: 02-07-2019 / 15-12-2021
# Data for Marek BELKA with party : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member written to CSV.
# Extracted Party: : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Vice-Chair, Date: 16-12-2021 / 15-07-2024
# Data for Marek BELKA with party : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Vice-Chair written to CSV.
# Processing MEP 102/929: https://www.europarl.europa.eu/meps/en/197534
# Extracted Name: François-Xavier BELLAMY
# Extracted Country: France
#
# 							 - Les Républicains (France)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197534/FRANÇOIS-XAVIER_BELLAMY/history/9#detailedcardmep
# Extracted Party: : Group of the European People's Party (Christian Democrats) - Member, Date: 02-07-2019 / 15-07-2024
# Data for François-Xavier BELLAMY with party : Group of the European People's Party (Christian Democrats) - Member written to CSV.
# Processing MEP 103/929: https://www.europarl.europa.eu/meps/en/197658
# Extracted Name: Adrian-Dragoş BENEA
# Extracted Country: Romania
#
# 							 - Partidul Social Democrat (Romania)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197658/ADRIAN-DRAGOŞ_BENEA/history/9#detailedcardmep
# ...
# Processing MEP 897/929: https://www.europarl.europa.eu/meps/en/197511
# Extracted Name: Salima YENBOU
# Extracted Country: France
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197511/SALIMA_YENBOU/history/9#detailedcardmep
# Extracted Party: : Group of the Greens/European Free Alliance - Member, Date: 02-07-2019 / 08-03-2022
# Data for Salima YENBOU with party : Group of the Greens/European Free Alliance - Member written to CSV.
#
party : Group of the European People's Party (Christian Democrats) - Member written to CSV.
# Processing MEP 905/929: https://www.europarl.europa.eu/meps/en/124780
# Extracted Name: Marco ZANNI
# Extracted Country: Italy
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/124780/MARCO_ZANNI/history/9#detailedcardmep
# Extracted Party: : Identity and Democracy Group - Chair, Date: 02-07-2019 / 15-07-2024
# Data for Marco ZANNI with party : Identity and Democracy Group - Chair written to CSV.
# Processing MEP 906/929: https://www.europarl.europa.eu/meps/en/197606
# Extracted Name: Javier ZARZALEJOS
# Extracted Country: Spain
#
# 							 - Partido Popular (Spain)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197606/JAVIER_ZARZALEJOS/history/9#detailedcardmep
# Extracted Party: : Group of the European People's Party (Christian Democrats) - Member, Date: 02-07-2019 / 15-07-2024
# Data for Javier ZARZALEJOS with party : Group of the European People's Party (Christian Democrats) - Member written to CSV.
# Processing MEP 907/929: https://www.europarl.europa.eu/meps/en/124713
# Extracted Name: Tomáš ZDECHOVSKÝ
# Extracted Country: Czechia
#
# 							 - Křesťanská a demokratická unie - Československá strana lidová (Czechia)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/124713/TOMÁŠ_ZDECHOVSKÝ/history/9#detailedcardmep
# Extracted Party: : Group of the European People's Party (Christian Democrats) - Member, Date: 02-07-2019 / 15-07-2024
# Data for Tomáš ZDECHOVSKÝ with party : Group of the European People's Party (Christian Democrats) - Member written to CSV.
# Processing MEP 908/929: https://www.europarl.europa.eu/meps/en/28615
# Extracted Name: Roberts ZĪLE
# Extracted Country: Latvia
#
# 							 - Nacionālā apvienība "Visu Latvijai!"-"Tēvzemei un Brīvībai/LNNK" (Latvia)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/28615/ROBERTS_ZĪLE/history/9#detailedcardmep
# Extracted Party: : European Conservatives and Reformists Group - Vice-Chair, Date: 02-07-2019 / 04-04-2022
# Data for Roberts ZĪLE with party : European Conservatives and Reformists Group - Vice-Chair written to CSV.
# Extracted Party: : European Conservatives and Reformists Group - Member of the Bureau, Date: 05-04-2022 / 15-07-2024
# Data for Roberts ZĪLE with party : European Conservatives and Reformists Group - Member of the Bureau written to CSV.
# Processing MEP 909/929: https://www.europarl.europa.eu/meps/en/197489
# Extracted Name: Bernhard ZIMNIOK
# Extracted Country: Germany
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197489/BERNHARD_ZIMNIOK/history/9#detailedcardmep
# Extracted Party: : Identity and Democracy Group - Member, Date: 02-07-2019 / 22-05-2024
# Data for Bernhard ZIMNIOK with party : Identity and Democracy Group - Member written to CSV.
# Extracted Party: : Non-attached Members, Date: 23-05-2024 / 15-07-2024
# Data for Bernhard ZIMNIOK with party : Non-attached Members written to CSV.
# Processing MEP 910/929: https://www.europarl.europa.eu/meps/en/124884
# Extracted Name: Kosma ZŁOTOWSKI
# Extracted Country: Poland
#
# 							 - Prawo i Sprawiedliwość (Poland)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/124884/KOSMA_ZŁOTOWSKI/history/9#detailedcardmep
# Extracted Party: : European Conservatives and Reformists Group - Co-treasurer, Date: 02-07-2019 / 15-07-2024
# Data for Kosma ZŁOTOWSKI with party : European Conservatives and Reformists Group - Co-treasurer written to CSV.
# Processing MEP 911/929: https://www.europarl.europa.eu/meps/en/197621
# Extracted Name: Juan Ignacio ZOIDO ÁLVAREZ
# Extracted Country: Spain
#
# 							 - Partido Popular (Spain)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/197621/JUAN_IGNACIO_ZOIDO_ÁLVAREZ/history/9#detailedcardmep
# Extracted Party: : Group of the European People's Party (Christian Democrats) - Member, Date: 02-07-2019 / 15-07-2024
# Data for Juan Ignacio ZOIDO ÁLVAREZ with party : Group of the European People's Party (Christian Democrats) - Member written to CSV.
# Processing MEP 912/929: https://www.europarl.europa.eu/meps/en/124739
# Extracted Name: Carlos ZORRINHO
# Extracted Country: Portugal
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/124739/CARLOS_ZORRINHO/history/9#detailedcardmep
# Extracted Party: : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member, Date: 02-07-2019 / 15-07-2024
# Data for Carlos ZORRINHO with party : Group of the Progressive Alliance of Socialists and Democrats in the European Parliament - Member written to CSV.
# Processing MEP 913/929: https://www.europarl.europa.eu/meps/en/185341
# Extracted Name: Željana ZOVKO
# Extracted Country: Croatia
#
# 							 - Hrvatska demokratska zajednica (Croatia)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/185341/ŽELJANA_ZOVKO/history/9#detailedcardmep
# Extracted Party: : Group of the European People's Party (Christian Democrats) - Member, Date: 02-07-2019 / 24-01-2022
# Data for Željana ZOVKO with party : Group of the European People's Party (Christian Democrats) - Member written to CSV.
# Extracted Party: : Group of the European People's Party (Christian Democrats) - Vice-Chair, Date: 25-01-2022 / 15-07-2024
# Data for Željana ZOVKO with party : Group of the European People's Party (Christian Democrats) - Vice-Chair written to CSV.
# Processing MEP 914/929: https://www.europarl.europa.eu/meps/en/125237
# Extracted Name: Marco ZULLO
# Extracted Country: Italy
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/125237/MARCO_ZULLO/history/9#detailedcardmep
# Extracted Party: : Non-attached Members, Date: 02-07-2019 / 10-03-2021
# Data for Marco ZULLO with party : Non-attached Members written to CSV.
# Extracted Party: : Renew Europe Group - Member, Date: 11-03-2021 / 15-07-2024
# Data for Marco ZULLO with party : Renew Europe Group - Member written to CSV.
# Processing MEP 915/929: https://www.europarl.europa.eu/meps/en/96933
# Extracted Name: Milan ZVER
# Extracted Country: Slovenia
#
# 							 - Slovenska demokratska stranka (Slovenia)
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/96933/MILAN_ZVER/history/9#detailedcardmep
# Extracted Party: : Group of the European People's Party (Christian Democrats) - Member, Date: 02-07-2019 / 15-07-2024
# Data for Milan ZVER with party : Group of the European People's Party (Christian Democrats) - Member written to CSV.
# Processing MEP 916/929: https://www.europarl.europa.eu/meps/en/28619
# Extracted Name: Tatjana ŽDANOKA
# Extracted Country: Latvia
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/28619/TATJANA_ŽDANOKA/history/9#detailedcardmep
# Extracted Party: : Group of the Greens/European Free Alliance - Member, Date: 02-07-2019 / 31-03-2022
# Data for Tatjana ŽDANOKA with party : Group of the Greens/European Free Alliance - Member written to CSV.
# Extracted Party: : Non-attached Members, Date: 01-04-2022 / 15-07-2024
# Data for Tatjana ŽDANOKA with party : Non-attached Members written to CSV.
# Processing MEP 917/929: https://www.facebook.com/share.php?u=https://www.europarl.europa.eu/meps/en/directory/9
# Extracted Name: N/A
# Extracted Country: N/A
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep
# Error accessing detailed history page https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep: 404 Client Error:  for url: https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep
# Processing MEP 918/929: https://twitter.com/intent/tweet?url=https://www.europarl.europa.eu/meps/en/directory/9&text=Directory&via=Europarl_EN
# Extracted Name: N/A
# Extracted Country: N/A
# Warning: No MEP ID found in URL https://twitter.com/intent/tweet?url=https://www.europarl.europa.eu/meps/en/directory/9&text=Directory&via=Europarl_EN
# Processing MEP 919/929: https://www.linkedin.com/sharing/share-offsite?url=https://www.europarl.europa.eu/meps/en/directory/9
# Extracted Name: N/A
# Extracted Country: N/A
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep
# Error accessing detailed history page https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep: 404 Client Error:  for url: https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep
# Processing MEP 920/929: https://api.whatsapp.com/send?text=https://www.europarl.europa.eu/meps/en/directory/9
# Extracted Name: N/A
# Extracted Country: N/A
# Fetching detailed history page: https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep
# Error accessing detailed history page https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep: 404 Client Error:  for url: https://www.europarl.europa.eu/meps/en/9/N/A/history/9#detailedcardmep
# Processing MEP 921/929: https://www.europarl.europa.eu/meps/en/search/advanced?groupCode=7018
# Extracted Name: N/A
# Extracted Country: N/A
# Warning: No MEP ID found in URL /meps/en/search/advanced?groupCode=7018
# Processing MEP 922/929: https://www.europarl.europa.eu/meps/en/search/advanced?groupCode=7038
# Extracted Name: N/A
# Extracted Country: N/A
# Warning: No MEP ID found in URL /meps/en/search/advanced?groupCode=7038
# Processing MEP 923/929: https://www.europarl.europa.eu/meps/en/search/advanced?groupCode=7150
# Extracted Name: N/A
# Extracted Country: N/A
# Warning: No MEP ID found in URL /meps/en/search/advanced?groupCode=7150
# Processing MEP 924/929: https://www.europarl.europa.eu/meps/en/search/advanced?groupCode=7037
# Extracted Name: N/A
# Extracted Country: N/A
# Warning: No MEP ID found in URL /meps/en/search/advanced?groupCode=7037
# Processing MEP 925/929: https://www.europarl.europa.eu/meps/en/search/advanced?groupCode=7035
# Extracted Name: N/A
# Extracted Country: N/A
# Warning: No MEP ID found in URL /meps/en/search/advanced?groupCode=7035
# Processing MEP 926/929: https://www.europarl.europa.eu/meps/en/search/advanced?groupCode=7028
# Extracted Name: N/A
# Extracted Country: N/A
# Warning: No MEP ID found in URL /meps/en/search/advanced?groupCode=7028
# Processing MEP 927/929: https://www.europarl.europa.eu/meps/en/search/advanced?groupCode=7036
# Extracted Name: N/A
# Extracted Country: N/A
# Warning: No MEP ID found in URL /meps/en/search/advanced?groupCode=7036
# Processing MEP 928/929: https://www.europarl.europa.eu/meps/en/search/advanced?groupCode=7151
# Extracted Name: N/A
# Extracted Country: N/A
# Warning: No MEP ID found in URL /meps/en/search/advanced?groupCode=7151
# Processing MEP 929/929: https://www.europarl.europa.eu/meps/en/search/advanced?groupCode=6561
# Extracted Name: N/A
# Extracted Country: N/A
# Warning: No MEP ID found in URL /meps/en/search/advanced?groupCode=6561
# Data successfully saved to C:\Users\pablo\OneDrive\Escritorio\Masters\Year_2\eu_database_project\mep_data\2019_2024_CRE9\raw\raw_mep_data_CRE-9.csv

# %%
#pre processing
import os
import pandas as pd

# Source and destination directories
source_dir = 
destination_dir = 

# List of European countries and their acronyms
country_to_acronym = {
    'Belgium': 'BE', 'Greece': 'EL', 'Lithuania': 'LT', 'Portugal': 'PT',
    'Bulgaria': 'BG', 'Spain': 'ES', 'Luxembourg': 'LU', 'Romania': 'RO',
    'Czechia': 'CZ', 'France': 'FR', 'Hungary': 'HU', 'Slovenia': 'SI',
    'Denmark': 'DK', 'Croatia': 'HR', 'Malta': 'MT', 'Slovakia': 'SK',
    'Germany': 'DE', 'Italy': 'IT', 'Netherlands': 'NL', 'Finland': 'FI',
    'Estonia': 'EE', 'Cyprus': 'CY', 'Austria': 'AT', 'Sweden': 'SE',
    'Ireland': 'IE', 'Latvia': 'LV', 'Poland': 'PL', 'United Kingdom': 'UK'
}

# Dictionary mapping group names to their acronyms
group_to_acronym = {
    'European People\'s Party–European Democrats': 'EPP-ED',
    'Group of the European People\'s Party (Christian Democrats) and European Democrats': 'EPP-ED',
    'Group of the European People\'s Party (Christian': 'EPP',
    'Party of European Socialists': 'PES',
    'Socialist Group in the European Parliament':'PES',
    'Alliance of Liberals and Democrats for Europe': 'ALDE',
    'Greens/European Free Alliance': 'G/EFA',
    'European United Left-Nordic Green Left': 'EUL-NGL',
    'Confederal Group of the European United Left': 'EUL-NGL',
    'Independence/Democracy': 'IND/DEM',
    'Union for a Europe of Nations': 'UEN',
    'Union for Europe of the Nations Group' : 'UEN',
    'Identity, Tradition, Sovereignty': 'ITS',
    'Identity, Tradition and Sovereignty Group': 'ITS',
    'Non-Inscrits': 'NI',
    'Group for a Europe of Democracies and Diversities': 'EDD',
    'Group of the European Liberal, Democrat and Reform Party' : 'ELDR',
    'Technical Group of Independent Members' : 'TGI',
    'The Green Group in the European Parliament': 'G',
    'Group of the European Radical Alliance': 'ERA',
    'Group of the European Democratic Alliance' : 'EDA',
    'Group of Independents for a Europe of Nations': 'IEN',
    'Europe of Nations Group (Coordination Group)': 'EN',
    'Group Union for Europe': 'UFE',
    'Forza Europa Group': 'FE',
    'Europe of freedom and democracy Group': 'EFD',
    'European Conservatives and Reformists Group': 'ECR',
    'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament': 'S&D',
    'Europe of Freedom and Direct Democracy Group': 'EFD',
    'Europe of Nations and Freedom Group': 'ENF',
    'The Left group in the European Parliament': 'GUE-NGL',
    'Renew Europe Group' : 'Renew',
    'Identity and Democracy Group': 'ID',
    'Group of the European United Left': 'GUE-NGL'
}

# Function to clean the 'Country' column by taking only the first word
def clean_country_name(country):
    if pd.notnull(country):
        # Split by space or special characters like '-' or '(' and take the first part
        first_word = country.split()[0]
        # Map to the acronym if available, otherwise return the cleaned first word
        return country_to_acronym.get(first_word, first_word)
    return country

# Function to clean the 'Party' column
def clean_party_name(party):
    if pd.notnull(party):
        if party.lower().startswith('non-'):
            return party  # Preserve the entire name if it starts with 'Non-'
        else:
            return party.split('-')[0].strip()  # Remove text after hyphen for other cases
    return party

# Replace group names with acronyms in the 'Party' column
def replace_party_name(party):
    for group_name, acronym in group_to_acronym.items():
        if group_name in party:
            return acronym
    return party

# Process each CSV file in the source directory
for file_name in os.listdir(source_dir):
    if file_name.endswith('.csv'):
        file_path = os.path.join(source_dir, file_name)

        # Load the CSV file
        df = pd.read_csv(file_path)

        # Clean the 'Country' column using the updated function
        df['Country'] = df['Country'].apply(clean_country_name)

        # Apply the cleaning function to the 'Party' column
        df['Party'] = df['Party'].apply(clean_party_name)

        # Replace group names with acronyms in the 'Party' column
        df['Party'] = df['Party'].apply(lambda x: replace_party_name(x) if pd.notnull(x) else x)

        # Replace any text containing 'Non' with 'NI'
        df['Party'] = df['Party'].apply(lambda x: 'NI' if pd.notnull(x) and 'Non' in x else x)

        # Create the cleaned file path
        cleaned_file_path = os.path.join(destination_dir, file_name)

        # Save the cleaned DataFrame back to a CSV file
        df.to_csv(cleaned_file_path, index=False)

        print(f"Cleaned data saved to {cleaned_file_path}")
# Out:
# Cleaned data saved to C:\Users\pablo\OneDrive\Escritorio\Masters\Year_2\eu_database_project\mep_data\1994-1999_CRE-4\clean\raw_mep_data_CRE-4.csv

# %%
#Tests results
import pandas as pd
import matplotlib.pyplot as plt

# File path to the CSV file
csv_file_path = 

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Function to plot frequency bar graphs and print frequency tables
def plot_and_print_frequency(data, title, xlabel, ylabel, output_file):
    # Calculate frequency table
    frequency_table = data.value_counts().sort_index()

    # Print the frequency table
    print(f"Frequency table for {title}:")
    print(frequency_table)
    print("\n" + "-"*40 + "\n")

    # Plot the frequency bar graph
    plt.figure(figsize=(10, 6))
    frequency_table.plot(kind='bar')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.savefig(output_file)
    plt.show()

# Plot the frequency bar graph and print the table for 'Country'
plot_and_print_frequency(df['Country'], 'Frequency of MEPs by Country', 'Country', 'Frequency', 'country_frequency.png')

# Plot the frequency bar graph and print the table for 'Party'
plot_and_print_frequency(df['Party'], 'Frequency of MEPs by Party', 'Party', 'Frequency', 'party_frequency.png')

print("Graphs have been saved as 'country_frequency.png' and 'party_frequency.png'.")
# Out:
# Frequency table for Frequency of MEPs by Country:
# Country
# AT    11
# BE    15
# BG     9
# CY     5
# CZ    15
# DE    62
# DK    11
# EE     1
# EL    24
# ES    44
# FI    16
# FR    66
# HR     8
# HU    21
# IE    17
# IT    95
# LT     7
# LU     3
# LV     7
# MT     5
# NL    27
# PL    44
# PT    35
# RO    21
# SE    15
# SI     5
# SK    13
# UK    78
# Name: count, dtype: int64
#
# ----------------------------------------
# Frequency table for Frequency of MEPs by Party:
# Party
# ECR        104
# EPP        239
# G/EFA      104
# GUE-NGL     89
# ID          85
# NI         126
# Renew      145
# S&D        194
# Name: count, dtype: int64
#
# ----------------------------------------
# Graphs have been saved as 'country_frequency.png' and 'party_frequency.png'.

# %%
#Tests results
import pandas as pd

# Path to the CSV file
file_path = 

# Load the CSV file
df = pd.read_csv(file_path)

# Drop duplicate names, keeping only unique ones
unique_names = df['Name'].drop_duplicates()

# Count the number of unique names
unique_name_count = unique_names.count()

# Print the result
print(f"Number of unique names: {unique_name_count}")
# Out:
# Number of unique names: 873
